# %%
#1.Прочитайте csv файл (використовуйте функцію read_csv)
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/IT/bestsellers with categories.csv")
print(df)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#2.Виведіть перші п'ять рядків (використовується функція head)
print(df.head(6))
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5       George R. R. Martin          4.4    12643     11  2011      Fiction

# %%
#3.Виведіть розміри датасету (використовуйте атрибут shape)
print(df.shape)
# Out:
# (550, 7)

# %%
#4.Відповідь: Про скільки книг зберігає дані датасет? 351
print(df.drop_duplicates(subset = 'Name'))
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 538  Winter of the World: Book Two of the Century T...
# 539  Women Food and God: An Unexpected Path to Almo...
# 540                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#5.Давайте змінимо регістр на малий, а пробіл замінимо на нижнє підкреслення (snake_style).
df.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
print(df)
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# # **Первинне дослідження даних**

# %%
#6.Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків (na) у кожному зі стовпців (використовуйте функції isna та sum)
#Відповідь: Чи є в якихось змінних пропуски? ні
print(df.isna().sum())
# Out:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %%
#7.Перевірте, які є унікальні значення в колонці genre (використовуйте функцію unique)
#Відповідь: Які є унікальні жанри? 'Non Fiction' 'Fiction'
print(df.genre.unique())
# Out:
# ['Non Fiction' 'Fiction']

# %%
#8.Тепер подивіться на розподіл цін: побудуйте діаграму (використовуйте kind='hist')
import matplotlib.pyplot as plt
df.price.plot(kind='hist')
plt.xlabel("Ціна", fontsize="small", color="midnightblue")
plt.ylabel("Кількість", fontsize="small", color="midnightblue")
plt.title("Розподіл цін", fontsize=15)
plt.show()

# %%
#9.Визначте, яка ціна у нас максимальна, мінімальна, середня, медіанна (використовуйте функції max, min, mean, median)
#Відповідь: Максимальна ціна? 105.00
#Відповідь: Мінімальна ціна? 0.00
#Відповідь: Середня ціна? 13.10
#Відповідь: Медіанна ціна? 11.0
print(df.price.describe().round(2))
print(df.price.median())
# Out:
# count    550.00
# mean      13.10
# std       10.84
# min        0.00
# 25%        7.00
# 50%       11.00
# 75%       16.00
# max      105.00
# Name: price, dtype: float64
# 11.0

# %% [markdown]
# # **Пошук та сортування даних**

# %%
#10.Відповідь: Який рейтинг у датасеті найвищий? Відповідь: 4.9
print(df.user_rating.max())
# Out:
# 4.9

# %%
#11.Відповідь: Скільки книг мають такий рейтинг? Відповідь: 52
print(len(df[df.user_rating == max]))
# Out:
# 52

# %%
#12.Відповідь: Яка книга має найбільше відгуків? Відповідь: Where the Crawdads Sing
dfm = df[df.reviews == df.reviews.max()]
print(dfm.name)
# Out:
# 534    Where the Crawdads Sing
# Name: name, dtype: object

# %%
#13.Відповідь: З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)? Відповідь: Publication Manual of the American Psychological Association, 6th Edition
dfy = df[df.year == 2015]
dfb = dfy[dfy.price == dfy.price.max()]
print(dfb.name)
# Out:
# 277    Publication Manual of the American Psychologic...
# Name: name, dtype: object

# %%
#14.Відповідь: Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)? Відповідь: 20
print(len(df[(df.year == 2010) & (df.genre == 'Fiction')]))
# Out:
# 20

# %%
#15.Відповідь: Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)? Відповідь: 1
print(len(df[(df.year == 2010 | 2011) & (df.user_rating == 4.9)]))
# Out:
# 1

# %%
#16.І насамкінець, давайте відсортуємо за зростанням ціни всі книги, які потрапили до рейтингу в 2015 році і коштують дешевше за 8 доларів (використовуйте функцію sort_values).
#Відповідь: Яка книга остання у відсортованому списку? Відповідь: Old School (Diary of a Wimpy Kid #10)
dfl = df[(df.year == 2015) & (df.price < 8)].sort_values(by=['price'], ascending=True)
print(dfl.name[-1:])
# Out:
# 253    Old School (Diary of a Wimpy Kid #10)
# Name: name, dtype: object

# %% [markdown]
# # **Агрегування даних та з'єднання таблиць**

# %%
#17.Для початку давайте подивимося на максимальну та мінімальну ціни для кожного з жанрів (використовуйте функції groupby та agg, для підрахунку мінімальних та максимальних
#   значень використовуйте max та min). Не беріть усі стовпці, виберіть тільки потрібні вам

# Відповідь: Максимальна ціна для жанру Fiction: Відповідь      82

# Відповідь: Мінімальна ціна для жанру Fiction: Відповідь       0

# Відповідь: Максимальна ціна для жанру Non Fiction: Відповідь  105

# Відповідь: Мінімальна ціна для жанру Non Fiction: Відповідь   0

a = df.sort_values(by=['price'], ascending=False).groupby(['genre']).agg({'price':['max', 'min']})
print(a)
# Out:
#             price
#               max min
# genre
# Fiction        82   0
# Non Fiction   105   0

# %%
#18.Тепер створіть новий датафрейм, який вміщатиме кількість книг для кожного з авторів (використовуйте функції groupby та agg, для підрахунку кількості використовуйте count).
#   Не беріть усі стовпці, виберете тільки потрібні

# Відповідь: Якої розмірності вийшла таблиця? Відповідь: 248 rows x 1 columns

# Відповідь: Який автор має найбільше книг? Відповідь:  Jeff Kinney

# Відповідь: Скільки книг цього автора? Відповідь: 12

new_df = df.groupby(['author']).agg({'name': ['count']})
print(new_df)
new_df.columns = ['books']
a = new_df[new_df.books == new_df.books.max()]
print(a)
# Out:
#                             name
#                            count
# author
# Abraham Verghese               2
# Adam Gasiewski                 1
# Adam Mansbach                  1
# Adir Levy                      1
# Admiral William H. McRaven     1
# ...                          ...
# Walter Isaacson                3
# William Davis                  2
# William P. Young               2
# Wizards RPG Team               3
# Zhi Gang Sha                   2
#
# [248 rows x 1 columns]
#              books
# author
# Jeff Kinney     12

# %%
#19.Тепер створіть другий датафрейм, який буде вміщати середній рейтинг для кожного автора (використовуйте функції groupby та agg, для підрахунку середнього
#   значення використовуйте mean). Не беріть усі стовпці, виберете тільки потрібні

# Відповідь: У якого автора середній рейтинг мінімальний? Відповідь: Donna Tartt

# Відповідь: Який у цього автора середній рейтинг? Відповідь: 3.9
dfr = df.groupby(['author']).agg({'user_rating': ['mean']}).round(1)
dfr.columns = ['author_rating']
print(dfr)
a = dfr[dfr.author_rating == dfr.author_rating.min()]
print(a)
# Out:
#                             author_rating
# author
# Abraham Verghese                      4.6
# Adam Gasiewski                        4.4
# Adam Mansbach                         4.8
# Adir Levy                             4.8
# Admiral William H. McRaven            4.7
# ...                                   ...
# Walter Isaacson                       4.6
# William Davis                         4.4
# William P. Young                      4.6
# Wizards RPG Team                      4.8
# Zhi Gang Sha                          4.6
#
# [248 rows x 1 columns]
#              author_rating
# author
# Donna Tartt            3.9

# %%
#20.З'єднайте останні два датафрейми так, щоб для кожного автора було видно кількість книг та середній рейтинг (Використовуйте функцію concat з параметром axis=1).
# Збережіть результат у змінну
employees = pd.concat([new_df, dfr], axis=1)
print(employees)
# Out:
#                             books  author_rating
# author
# Abraham Verghese                2            4.6
# Adam Gasiewski                  1            4.4
# Adam Mansbach                   1            4.8
# Adir Levy                       1            4.8
# Admiral William H. McRaven      1            4.7
# ...                           ...            ...
# Walter Isaacson                 3            4.6
# William Davis                   2            4.4
# William P. Young                2            4.6
# Wizards RPG Team                3            4.8
# Zhi Gang Sha                    2            4.6
#
# [248 rows x 2 columns]

# %%
#21.Відсортуйте датафрейм за зростаючою кількістю книг та зростаючим рейтингом (використовуйте функцію sort_values)

#Відповідь: Який автор перший у списку? Muriel Barbery
print(employees.sort_values(by = ['books', 'author_rating']))
# Out:
#                                     books  author_rating
# author
# Muriel Barbery                          1            4.0
# Chris Cleave                            1            4.1
# Ian K. Smith M.D.                       1            4.1
# Pierre Dukan                            1            4.1
# Elizabeth Strout                        1            4.2
# ...                                   ...            ...
# American Psychological Association     10            4.5
# Gary Chapman                           11            4.7
# Suzanne Collins                        11            4.7
# Rick Riordan                           11            4.8
# Jeff Kinney                            12            4.8
#
# [248 rows x 2 columns]

# %% [markdown]
# # **Візуалізація**

# %%
import matplotlib.pyplot as plt
import numpy as np
users_rating['count'].plot(kind="bar", color=np.random.rand (len(users_rating['count']),3))
plt.xlabel("Рейтинг", fontsize="medium", color="black")
plt.ylabel("Кількість книг", fontsize="medium", color="black")
plt.title( "Кількість книг за рейтингом", fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6, 60))
dfr['author_rating'].plot(kind="barh", color=np.random.rand (len(users_rating['count']),3))
plt.xlabel("Рейтинг", fontsize="x-large", color="black")
plt.ylabel("Автор", fontsize="medium", color="black")
plt.title( "Cередній рейтинг для кожного автора", fontsize=15, fontweight="demi")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 133 (\x85) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
plt.figure(figsize=(10, 5))
sns.boxenplot(data=df, x='user_rating', y='price', palette='spring')
plt.title("Розподіл цін за рейтингами")
plt.xlabel("Рейтинг")
plt.ylabel("Ціна")
plt.xticks(rotation=45)
plt.show()
